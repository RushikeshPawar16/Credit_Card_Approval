# %%
#!pip install --user pycaret

# %%
# conda install -c conda-forge xgboost

# %%
import pandas as pd
df=pd.read_csv('Feature_Selection.csv')
df.head()
# Out:
#    Age   Debt  EducationLevel  YearsEmployed  PriorDefault  Employed  \
# 0  327  4.460              11           3.04             1         1
# 1   89  0.500              11           1.50             1         0
# 2  125  1.540              13           3.75             1         1
# 3   43  5.625              13           1.71             1         0
# 4  167  4.000              10           2.50             1         0
#
#    CreditScore  Citizen  ZipCode       Income  Approved
# 0            6        0       11   560.000000         0
# 1            0        0       95   824.000000         0
# 2            5        0       31     3.000000         0
# 3            0        2       37  1018.862119         0
# 4            0        0      114  1018.862119         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             689 non-null    int64
#  1   Debt            689 non-null    float64
#  2   EducationLevel  689 non-null    int64
#  3   YearsEmployed   689 non-null    float64
#  4   PriorDefault    689 non-null    int64
#  5   Employed        689 non-null    int64
#  6   CreditScore     689 non-null    int64
#  7   Citizen         689 non-null    int64
#  8   ZipCode         689 non-null    int64
#  9   Income          689 non-null    float64
#  10  Approved        689 non-null    int64
# dtypes: float64(3), int64(8)
# memory usage: 59.3 KB

# %%
from pycaret.classification import *
clf=setup(data=df,target='Approved')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_8207e874_d188_11ea_87e9_8c164558b182" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8207e874_d188_11ea_87e9_8c164558b182level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8207e874_d188_11ea_87e9_8c164558b182row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_8207e874_d188_11ea_87e9_8c164558b182row0_col1" class="data row0 col1" >8624</td>
#             </tr>
#             <tr>
#                         <th id="T_8207e874_d188_11ea_87e9_8c164558b182level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8207e874_d188_11ea_87e9_8c164558b182row1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
compare_models()
# Out:
# IntProgress(value=0, description='Processing: ', max=170)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              16:14:41
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# ETC        . . . . . . . . . . . . . . . . . .       Calculating ETC
# Empty DataFrame
# Columns: [Model, Accuracy, AUC, Recall, Prec., F1, Kappa]
# Index: []
# ---------------------------------------------------------------------------
# XGBoostLibraryNotFound                    Traceback (most recent call last)
# <ipython-input-6-9ff5ccfe3077> in <module>
# ----> 1 compare_models()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pycaret\classification.py in compare_models(blacklist, fold, round, sort, turbo)
#    3220     from sklearn.ensemble import ExtraTreesClassifier
#    3221     from sklearn.multiclass import OneVsRestClassifier
# -> 3222     from xgboost import XGBClassifier
# ...
